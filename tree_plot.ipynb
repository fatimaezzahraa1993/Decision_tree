# %%
from matplotlib import pyplot as plt
import pandas as pd
from sklearn.tree import DecisionTreeClassifier 
from sklearn import tree

# %%
iris_data = pd.read_csv('iris_data.csv')
iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data = iris_data[['sepal_length', 'sepal_width','petal_length', 'petal_width']]
target = iris_data['species']

# %%
dtc = DecisionTreeClassifier()
model = dtc.fit(data, target)

# %%
fig = plt.figure(figsize=(25,20))
fig = tree.plot_tree(dtc, 
                   feature_names=data.columns,  
                   class_names='species',
                   filled=True)

# %%
prediction = dtc.predict([[1, 5, 4, 5]])
prediction
# Out:
# array(['versicolor'], dtype=object)

# %%
prediction2 = dtc.predict([[4.5, 1.2, 0.3, 0.6]])
prediction2
# Out:
# array(['setosa'], dtype=object)
